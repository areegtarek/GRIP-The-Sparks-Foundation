# %% [markdown]
# <a href="https://colab.research.google.com/github/areegtarek/GRIP-The-Sparks-Foundation/blob/main/_2_IRIS_Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **by: Areeg Tarek**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Unsupervised learning: PCA and Find the optimum number of clusters**

# %% [markdown]
# # **Data Description**

# %% [markdown]
# - sepal length in cm
# - sepal width in cm
# - petal length in cm
# - petal width in cm
# - class: -- Iris Setosa -- Iris Versicolour -- Iris Virginica

# %% [markdown]
# # **Importing Necessary Libraries and datasets**

# %%
import pandas as pd
import numpy as np
from sklearn import datasets
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Importing the dataset 
iris = datasets.load_iris()
dataset = pd.DataFrame(iris.data, columns = iris.feature_names)

# %%
X = iris.data
y = iris.target

# %%
dataset.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %% [markdown]
# # **exploratory data analysis(EDA)**

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
# dtypes: float64(4)
# memory usage: 4.8 KB

# %%
dataset.duplicated().sum()
# Out:
# 1

# %%
dataset.drop_duplicates(inplace=True)

# %%
dataset.duplicated().sum()
# Out:
# 0

# %%
dataset.isnull().sum() #checking for total null values
# Out:
# sepal length (cm)    0
# sepal width (cm)     0
# petal length (cm)    0
# petal width (cm)     0
# dtype: int64

# %%
dataset.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# count         149.000000        149.000000         149.000000        149.000000
# mean            5.843624          3.059732           3.748993          1.194631
# std             0.830851          0.436342           1.767791          0.762622
# min             4.300000          2.000000           1.000000          0.100000
# 25%             5.100000          2.800000           1.600000          0.300000
# 50%             5.800000          3.000000           4.300000          1.300000
# 75%             6.400000          3.300000           5.100000          1.800000
# max             7.900000          4.400000           6.900000          2.500000

# %% [markdown]
# **Data Correlation:** is a way to understand the relationship betweem multiple variables and attributes

# %% [markdown]
# ![Correlation-1.jpg](data:image/jpeg;base64,...)

# %%
dataset.corr().style.background_gradient(cmap='Oranges')
# Out:
# <style type="text/css">
# #T_0125a_row0_col0, #T_0125a_row1_col1, #T_0125a_row2_col2, #T_0125a_row3_col3 {
#   background-color: #7f2704;
#   color: #f1f1f1;
# }
# #T_0125a_row0_col1 {
#   background-color: #fdd6ae;
#   color: #000000;
# }
# #T_0125a_row0_col2 {
#   background-color: #9a3103;
#   color: #f1f1f1;
# }
# #T_0125a_row0_col3 {
#   background-color: #a83703;
#   color: #f1f1f1;
# }
# #T_0125a_row1_col0, #T_0125a_row1_col2, #T_0125a_row1_col3, #T_0125a_row2_col1 {
#   background-color: #fff5eb;
#   color: #000000;
# }
# #T_0125a_row2_col0 {
#   background-color: #a13403;
#   color: #f1f1f1;
# }
# #T_0125a_row2_col3, #T_0125a_row3_col2 {
#   background-color: #862a04;
#   color: #f1f1f1;
# }
# #T_0125a_row3_col0 {
#   background-color: #b53b02;
#   color: #f1f1f1;
# }
# #T_0125a_row3_col1 {
#   background-color: #fff0e1;
#   color: #000000;
# }
# </style>
# <table id="T_0125a_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
# ...

# %% [markdown]
# # **Numerical data distribution**

# %% [markdown]
# pair plot represent the distrubution of each feature and the relation between them

# %%
plt.rcParams['figure.figsize'] = (40, 41)
sns.pairplot(dataset, palette = 'husl')
plt.title('Pair plot for the data', fontsize = 30)
plt.show()

# %% [markdown]
# # **Using PCA to reduce the dimensionality to 2 dimensions**

# %%
from sklearn import decomposition
# Using PCA from sklearn PCA
pca = decomposition.PCA(n_components=2)
X_centered = X - X.mean(axis=0)
pca.fit(X_centered)
X_pca = pca.transform(X_centered)

# Plotting the results of PCA
plt.plot(X_pca[y == 0, 0], X_pca[y == 0, 1], 'bo', label='Setosa')
plt.plot(X_pca[y == 1, 0], X_pca[y == 1, 1], 'go', label='Versicolour')
plt.plot(X_pca[y == 2, 0], X_pca[y == 2, 1], 'ro', label='Virginica')
plt.legend(loc=0);

# %%
#Finding the optimum number of clusters for k-means classification
from sklearn.cluster import KMeans
wcss = []

for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', max_iter = 300, n_init = 10, random_state = 0)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)

# %% [markdown]
# # **Using the elbow method to determine the optimal number of clusters for k-means clustering**

# %%
plt.plot(range(1, 11), wcss)
plt.title('The elbow method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS') #within cluster sum of squares
plt.show()

# %% [markdown]
# From this we choose the number of clusters as 3.

# %% [markdown]
# # **K-Means Clustering**

# %%
#Applying kmeans to the dataset / Creating the kmeans classifier
kmeans = KMeans(n_clusters = 3, init = 'k-means++', max_iter = 300, n_init = 10, random_state = 0)
y_kmeans = kmeans.fit_predict(X)

# %%
#Visualising the clusters
plt.scatter(X[y_kmeans == 0, 0], X[y_kmeans == 0, 1], s = 100, c = 'red', label = 'Iris-setosa')
plt.scatter(X[y_kmeans == 1, 0], X[y_kmeans == 1, 1], s = 100, c = 'blue', label = 'Iris-versicolour')
plt.scatter(X[y_kmeans == 2, 0], X[y_kmeans == 2, 1], s = 100, c = 'green', label = 'Iris-virginica')

#Plotting the centroids of the clusters
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:,1], s = 100, c = 'yellow', label = 'Centroids')

plt.legend()
